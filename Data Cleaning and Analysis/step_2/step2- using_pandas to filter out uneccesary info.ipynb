# %%
import pandas as pd

# %%
data = pd.read_excel("step_1.xlsx")

# %%
data
# Out:
#          Unnamed: 0 Unnamed: 1  fis  sales fis.1  sales.1 fis.2  sales.2 sam1  \
# 0    CA-2011-100293 2013-03-14  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 1    CA-2011-100706 2013-12-16  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 2    CA-2011-100895 2013-06-02  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 3    CA-2011-100916 2013-10-21  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 4    CA-2011-101266 2013-08-27  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# ..              ...        ...  ...    ...   ...      ...   ...      ...  ...
# 817  US-2014-166233 2016-07-03  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 818  US-2014-166611 2016-03-28  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 819  US-2014-167920 2016-12-09  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 820  US-2014-168116 2016-11-04  NaN    NaN   NaN      NaN   NaN      NaN  NaN
# 821  US-2014-168690 2016-01-08  NaN    NaN   NaN      NaN   NaN      NaN  NaN
#
# ...

# %%
first_class_cons = data[data["fis"] =="Consumer"]

# %%
first_class_cons
# Out:
#          Unnamed: 0 Unnamed: 1       fis    sales fis.1  sales.1 fis.2  \
# 11   CA-2011-103366 2013-01-15  Consumer  149.950   NaN      NaN   NaN
# 20   CA-2011-109043 2013-08-15  Consumer  243.600   NaN      NaN   NaN
# 29   CA-2011-113166 2013-12-24  Consumer    9.568   NaN      NaN   NaN
# 51   CA-2011-124023 2013-04-07  Consumer    8.960   NaN      NaN   NaN
# 63   CA-2011-130155 2013-05-19  Consumer   34.200   NaN      NaN   NaN
# ..              ...        ...       ...      ...   ...      ...   ...
# 769  US-2013-162677 2015-03-27  Consumer  187.616   NaN      NaN   NaN
# 772  US-2013-167472 2015-06-07  Consumer  678.870   NaN      NaN   NaN
# 778  US-2014-108063 2016-12-02  Consumer   34.650   NaN      NaN   NaN
# 794  US-2014-133781 2016-06-22  Consumer   37.608   NaN      NaN   NaN
# 803  US-2014-148831 2016-10-13  Consumer  348.560   NaN      NaN   NaN
#
#      sales.2 sam1  sales.3  ... sec2  sales.7 sec3  sales.8 sta1  sales.9  \
# ...

# %%
first_class_cor = data[data["fis.1"] =="Corporate"]

# %%
first_class_cor
# Out:
#          Unnamed: 0 Unnamed: 1  fis  sales      fis.1   sales.1 fis.2  \
# 10   CA-2011-103317 2013-07-05  NaN    NaN  Corporate   242.546   NaN
# 13   CA-2011-103989 2013-03-19  NaN    NaN  Corporate   590.762   NaN
# 15   CA-2011-106054 2013-01-06  NaN    NaN  Corporate    12.780   NaN
# 26   CA-2011-111934 2013-05-05  NaN    NaN  Corporate    47.320   NaN
# 53   CA-2011-124688 2013-08-27  NaN    NaN  Corporate  1812.010   NaN
# 55   CA-2011-125682 2013-11-22  NaN    NaN  Corporate     9.960   NaN
# 68   CA-2011-131905 2013-02-06  NaN    NaN  Corporate   321.560   NaN
# 126  CA-2011-163293 2013-09-08  NaN    NaN  Corporate   116.850   NaN
# 138  CA-2011-169684 2013-10-20  NaN    NaN  Corporate   426.942   NaN
# 153  CA-2012-104038 2014-02-06  NaN    NaN  Corporate   176.630   NaN
# 190  CA-2012-121720 2014-06-11  NaN    NaN  Corporate  3165.744   NaN
# 208  CA-2012-133396 2014-08-13  NaN    NaN  Corporate    64.680   NaN
# ...

# %%
first_class_hom = data[data["fis.2"] =="Home Office"]

# %%
first_class_hom
# Out:
#          Unnamed: 0 Unnamed: 1  fis  sales fis.1  sales.1        fis.2  \
# 69   CA-2011-132010 2013-10-13  NaN    NaN   NaN      NaN  Home Office
# 75   CA-2011-136567 2013-12-20  NaN    NaN   NaN      NaN  Home Office
# 81   CA-2011-140165 2013-05-13  NaN    NaN   NaN      NaN  Home Office
# 404  CA-2013-149454 2015-07-26  NaN    NaN   NaN      NaN  Home Office
# 428  CA-2013-159142 2015-04-05  NaN    NaN   NaN      NaN  Home Office
# 437  CA-2013-162159 2015-09-17  NaN    NaN   NaN      NaN  Home Office
# 520  CA-2014-121419 2016-04-02  NaN    NaN   NaN      NaN  Home Office
# 565  CA-2014-132213 2016-04-25  NaN    NaN   NaN      NaN  Home Office
# 597  CA-2014-144456 2016-09-08  NaN    NaN   NaN      NaN  Home Office
# 635  CA-2014-155292 2016-10-30  NaN    NaN   NaN      NaN  Home Office
# 766  US-2013-158309 2015-11-27  NaN    NaN   NaN      NaN  Home Office
# 813  US-2014-162558 2016-10-02  NaN    NaN   NaN      NaN  Home Office
#
# ...

# %%
first_class_cons.to_excel("first_class_cons1.xlsx")

# %%
first_class_cor.to_excel("first_class_cor.xlsx")

# %%
first_class_hom.to_excel("first_class_hom.xlsx")

# %%
#

# %%
same_day_cons = data[data["sam1"] =="Consumer"]

# %%
same_day_cor= data[data["sam2"] =="Corporate"]

# %%
same_day_hom= data[data["sam3"] =="Home Office"]

# %%
same_day_cons.to_excel("same_day_cons.xlsx")

# %%
same_day_cor.to_excel("same_day_cor.xlsx")

# %%
same_day_hom.to_excel("same_day_hom.xlsx")

# %%
second_class_cons = data[data["sec1"] =="Consumer"]

# %%
second_class_cor = data[data["sec2"] =="Corporate"]

# %%
second_class_hom = data[data["sec3"] =="Home Office"]

# %%
second_class_hom.to_excel("second_class_hom.xlsx")

# %%
second_class_cons.to_excel("second_class_cons.xlsx")

# %%
second_class_cor.to_excel("second_class_cor.xlsx")

# %%
standard_class_cons = data[data["sta1"] =="Consumer"]

# %%
standard_class_cor = data[data["sta2"] =="Corporate"]

# %%
standard_class_hom = data[data["sta3"] =="Home Office"]

# %%
standard_class_cons.to_excel("standard_class_cons.xlsx")

# %%
standard_class_cor.to_excel("standard_class_cor.xlsx")

# %%
standard_class_hom.to_excel("standard_class_hom.xlsx")
